# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

import tensorflow as tf
from tensorflow.keras import Model, layers
from tensorflow import keras

# %%
def load_data():
    '''
    Returns contents of data{0..1}.npy
    '''
    train_data = np.zeros((1, 40, 168))
    train_labels = np.zeros((1,))
    for i in range(2):
        tmp_data = np.load('./Data/data{}.npy'.format(i))
        tmp_labels = np.load('./Data/lab{}.npy'.format(i))        
        train_data = np.concatenate((train_data, tmp_data), axis = 0)
        train_labels = np.concatenate((train_labels, tmp_labels), axis = 0)
    return train_data[1:], train_labels[1:]

# %%
# del train_data, train_labels
train_data, train_labels = load_data()

# %%
def show_images(x, num = 100, caption = None):
    '''
    Args :
    x => (n * 40 * 168 array, containing n images)
    num => number of images to be shown
    caption => Array of size n * 1 containing captions to be put on top of the images
    '''
    k = 4
    assert num % k == 0, "Num must be a multiple of {}!".format(k)
    if caption is None:
        caption = np.arange(num)
#     assert caption.size == num, "Num must be a multiple of 10!"
    ratio = 168 / 40
    rows = num // k
    fig, axs = plt.subplots(rows, k, figsize = (k * ratio, rows))
    
    for i in range(rows):
        for j in range(k):
            h = i * k + j
            axs[i, j].imshow(x[h], cmap="gray")
            axs[i, j].axis('off')
            axs[i, j].set_title(caption[h])
            
    plt.tight_layout()

# %%
show_images(train_data, 20, caption = train_labels)

# %% [markdown]
# ## Architecture of the Model

# %% [markdown]
# ### The algorithm is deterministic rather than building a machine learning model for the same :
#
# * Layer 1 :
#  - Convolutinng a 28 * 28 filter but instead of multiplying it with a matrix, we pass it through a
#
# * Layer 2:
#  - Max Pooling 2D with filter size 13 * 141
#  - Input Shape: 13 * 141 * 10
#  - Output Shape: 10 * 1
#
# * Layer 3:
#  - The softmax is then multiplied by a vector A such that $ A_{i} = i $
#  - y = $ A^T . x $
#
# * Loss :
#  - Mean squared loss

# %% [markdown]
# ###  Loading a pretrained MNIST model

# %%
# MNIST = tf.keras.models.load_model('../../ML_notebooks/MNIST_pretrained')
MNIST = tf.keras.models.load_model('./KerasMNIST/cnn.h5')
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %%
# MNIST.build()

# %%
from tensorflow.keras.datasets import mnist
(_, _), (test_data, test_labels) = mnist.load_data()

# %%
print(test_data.shape)
# Out:
# (10000, 28, 28)

# %%
def predict(x):
    '''
    Arguments : 28 * 28 image
    Output : 10 * 1 vector
    '''
    m, i, j = x.shape
    x = x.reshape(m, i, j, 1).astype('float32') / 255
    out = MNIST.predict(x)
    return out

# %%
preds = predict(test_data)

# %%
p = np.argmax(preds, axis = 1)

# %%
show_images(test_data, 16, p)

# %% [markdown]
# ## Building the model as described above

# %%
def Convolutional_MNIST(inp):
    '''
    Args: 
    inp => argument of size 40 * 168
    outp => numpy array of size 13 * 141 * 10
    '''
    k, m, n = inp.shape
    ki = 28
    kj = 28
#     img_no = 3

    stridei = 1
    stridej = 18
    
    outx = (m - ki) // (stridei) + 1
    outy = (n - kj) // (stridej) + 1
    
    rows = (m - ki) // (stridei) + 1
    cols = (n - kj) // (stridej) + 1
    
    outp = np.zeros((k, outx, outy, 10))
    
    for i in range(0, m - ki + 1, stridei):
        for j in range(0, n - kj + 1, stridej):
            
            img = inp[:, i:i + ki, j:j + kj]
            pres = predict(img)
            outi = i // stridei
            outj = j // stridej
            outp[:, outi, outj] = pres
    return outp

# %%
k = train_data[:100]

# %%
h = Convolutional_MNIST(k)

# %%
q = np.max(h, axis = 1)
q.sort(axis = 1)
p = q[:,-5:-1, :]
l = p.argmax(axis = 2)
final = l.sum(axis = 1)

# %%
show_images(train_data, 40, final)

# %%
def batch_pred(data, start, end):
    k = train_data[start:end]
    h = Convolutional_MNIST(k)
    q = np.max(h, axis = 1)
    q.sort(axis = 1)
    p = q[:,-5:-1, :]
    l = p.argmax(axis = 2)
    final = l.sum(axis = 1)
    return final

# %%
final_sums = []

# %%
for i in range(0, 1000, 100):
    tmp_batch_sum = batch_pred(train_data, i, i + 100)
    final_sums.extend(tmp_batch_sum)

# %%
def plot_metrics(labels, Sums, num):
    sums = np.array(Sums)
    acc = (labels[num] == sums)
    loss = (labels[num] - sums) ** 2
    fig, ax = plt.subplots(1, 2, figsize = (10, 5))
    
    data = np.arange(0, num)
    ax[0].plot(data, loss)
    ax[0].set_xlabel("Samples")
    ax[0].set_ylabel("Loss")

    ax[1].plot(data, accuracies)
    ax[1].set_xlabel("Samples")
    ax[1].set_ylabel("Accuracy")
    fig.tight_layout()

# %%
plot_metrics(train_labels, final_sums, 1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-df6bb58483fd> in <module>
# ----> 1 plot_metrics(train_labels, final_sums, 1000)
#
# <ipython-input-38-886c1c7dabe7> in plot_metrics(labels, Sums, num)
#       1 def plot_metrics(labels, Sums, num):
# ----> 2     labels = np.array(Labels)
#       3     sums = np.array(Sums)
#       4     acc = (labels[num] == sums)
#       5     loss = (labels[num] - sums) ** 2
#
# NameError: name 'Labels' is not defined
